# %% [markdown]
# # 550 Group Project Data Explorations - SeaQuills

# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# %%
# !pip install -q xlrd #to use Excel
import pandas as pd

# %% [markdown]
# ## US Prosperity Index Data

# %% [markdown]
# ###USPI County Data

# %%
#uspi_cd = pd.read_excel('/content/gdrive/My Drive/550/DataSets/USPI_2021_County_Data.xlsx')
uspi_cd = pd.read_excel('Desktop/550/USPI_2021_County_Data.xlsx')
uspi_cd.head (20)
# Out:
#         area_name  area_code area_group  rank_2004  rank_2005  rank_2006  \
# 0       Adair, IA      19001         IA        202        202        211
# 1       Adair, KY      21001         KY        752        752        772
# 2       Adair, OK      40001         OK       1150       1148       1157
# 3       Adams, CO       8001         CO        409        409        412
# 4       Adams, IA      19003         IA        325        326        334
# 5       Adams, NE      31001         NE        296        293        269
# 6      Aitkin, MN      27001         MN        344        345        340
# 7     Alachua, FL      12001         FL        609        606        609
# 8     Alameda, CA       6001         CA        446        446        442
# 9     Alamosa, CO       8003         CO        368        371        375
# 10     Albany, NY      36001         NY        242        243        242
# 11    Alfalfa, OK      40003         OK        863        863        901
# ...

# %%
#Check summary statics
uspi_cd.describe()
# Out:
#           area_code    rank_2004    rank_2005    rank_2006    rank_2007  \
# count   1196.000000  1196.000000  1196.000000  1196.000000  1196.000000
# mean   27343.994983   598.500000   598.500000   598.500000   598.500000
# std    14143.758833   345.399768   345.399768   345.399768   345.399768
# min     6001.000000     1.000000     1.000000     1.000000     1.000000
# 25%    13224.500000   299.750000   299.750000   299.750000   299.750000
# 50%    27062.000000   598.500000   598.500000   598.500000   598.500000
# 75%    40063.500000   897.250000   897.250000   897.250000   897.250000
# max    48507.000000  1196.000000  1196.000000  1196.000000  1196.000000
#
#          rank_2008    rank_2009    rank_2010    rank_2011    rank_2012  ...  \
# count  1196.000000  1196.000000  1196.000000  1196.000000  1196.000000  ...
# mean    598.500000   598.500000   598.500000   598.500000   598.500000  ...
# std     345.399768   345.399768   345.399768   345.399768   345.399768  ...
# ...

# %%
#summary of cells with nulls
uspi_cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1196 entries, 0 to 1195
# Data columns (total 39 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_name   1196 non-null   object
#  1   area_code   1196 non-null   int64
#  2   area_group  1196 non-null   object
#  3   rank_2004   1196 non-null   int64
#  4   rank_2005   1196 non-null   int64
#  5   rank_2006   1196 non-null   int64
#  6   rank_2007   1196 non-null   int64
#  7   rank_2008   1196 non-null   int64
#  8   rank_2009   1196 non-null   int64
#  9   rank_2010   1196 non-null   int64
#  10  rank_2011   1196 non-null   int64
#  11  rank_2012   1196 non-null   int64
#  12  rank_2013   1196 non-null   int64
#  13  rank_2014   1196 non-null   int64
#  14  rank_2015   1196 non-null   int64
#  15  rank_2016   1196 non-null   int64
#  16  rank_2017   1196 non-null   int64
#  17  rank_2018   1196 non-null   int64
#  18  rank_2019   1196 non-null   int64
# ...

# %%
# Consider columns we don't need
list(uspi_cd.columns)
# Out:
# ['area_name',
#  'area_code',
#  'area_group',
#  'rank_2004',
#  'rank_2005',
#  'rank_2006',
#  'rank_2007',
#  'rank_2008',
#  'rank_2009',
#  'rank_2010',
#  'rank_2011',
#  'rank_2012',
#  'rank_2013',
#  'rank_2014',
#  'rank_2015',
#  'rank_2016',
#  'rank_2017',
#  'rank_2018',
#  'rank_2019',
#  'rank_2020',
#  'rank_2021',
#  'score_2004',
#  'score_2005',
#  'score_2006',
#  'score_2007',
#  'score_2008',
#  'score_2009',
#  'score_2010',
#  'score_2011',
#  'score_2012',
#  'score_2013',
#  'score_2014',
#  'score_2015',
#  'score_2016',
#  'score_2017',
#  'score_2018',
#  'score_2019',
#  'score_2020',
#  'score_2021']

# %% [markdown]
# ### 11 Pillars

# %%
#pillars = pd.read_excel('/content/gdrive/My Drive/550/DataSets/USPI_2021_County_Data.xlsx', sheet_name='Pillars x 11')

pillars = pd.read_excel('Desktop/550/USPI_2021_County_Data.xlsx', sheet_name='Pillars x 11')
pillars.head (22)
# Out:
#     area_name  area_code area_group           pillar_name  rank_2004  \
# 0   Adair, IA      19001         IA            Governance        245
# 1   Adair, IA      19001         IA      Personal Freedom        351
# 2   Adair, IA      19001         IA   Safety and Security        121
# 3   Adair, IA      19001         IA        Social Capital        168
# 4   Adair, IA      19001         IA  Business Environment        833
# 5   Adair, IA      19001         IA      Economic Quality        557
# 6   Adair, IA      19001         IA        Infrastructure        473
# 7   Adair, IA      19001         IA             Education        272
# 8   Adair, IA      19001         IA                Health        335
# 9   Adair, IA      19001         IA     Living Conditions        144
# 10  Adair, IA      19001         IA   Natural Environment        843
# 11  Adair, KY      21001         KY            Governance       1077
# 12  Adair, KY      21001         KY      Personal Freedom        532
# ...

# %%
#List the pillars and checking to make sure that spelling is consistent
pillars.pillar_name.unique()
# Out:
# array(['Governance', 'Personal Freedom', 'Safety and Security',
#        'Social Capital', 'Business Environment', 'Economic Quality',
#        'Infrastructure', 'Education', 'Health', 'Living Conditions',
#        'Natural Environment'], dtype=object)

# %%
#list of column names - we don't need all these columns
list(pillars.columns)
# Out:
# ['area_name',
#  'area_code',
#  'area_group',
#  'pillar_name',
#  'rank_2004',
#  'rank_2005',
#  'rank_2006',
#  'rank_2007',
#  'rank_2008',
#  'rank_2009',
#  'rank_2010',
#  'rank_2011',
#  'rank_2012',
#  'rank_2013',
#  'rank_2014',
#  'rank_2015',
#  'rank_2016',
#  'rank_2017',
#  'rank_2018',
#  'rank_2019',
#  'rank_2020',
#  'rank_2021',
#  'score_2004',
#  'score_2005',
#  'score_2006',
#  'score_2007',
#  'score_2008',
#  'score_2009',
#  'score_2010',
#  'score_2011',
#  'score_2012',
#  'score_2013',
#  'score_2014',
#  'score_2015',
#  'score_2016',
#  'score_2017',
#  'score_2018',
#  'score_2019',
#  'score_2020',
#  'score_2021']

# %%
pillars.describe()
# Out:
#           area_code     rank_2004     rank_2005     rank_2006     rank_2007  \
# count  13156.000000  13156.000000  13156.000000  13156.000000  13156.000000
# mean   27343.994983    591.488826    591.488826    591.488826    591.488826
# std    14138.382000    345.593880    345.593880    345.588223    345.379562
# min     6001.000000      1.000000      1.000000      1.000000      1.000000
# 25%    13224.500000    295.000000    295.000000    295.000000    292.000000
# 50%    27062.000000    581.000000    581.000000    581.000000    587.000000
# 75%    40063.500000    895.250000    895.250000    895.250000    895.250000
# max    48507.000000   1196.000000   1196.000000   1196.000000   1196.000000
#
#           rank_2008     rank_2009     rank_2010     rank_2011     rank_2012  \
# count  13156.000000  13156.000000  13156.000000  13156.000000  13156.000000
# mean     591.564153    591.611432    591.668668    591.677562    591.672849
# ...

# %%
pillars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13156 entries, 0 to 13155
# Data columns (total 40 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   area_name    13156 non-null  object
#  1   area_code    13156 non-null  int64
#  2   area_group   13156 non-null  object
#  3   pillar_name  13156 non-null  object
#  4   rank_2004    13156 non-null  int64
#  5   rank_2005    13156 non-null  int64
#  6   rank_2006    13156 non-null  int64
#  7   rank_2007    13156 non-null  int64
#  8   rank_2008    13156 non-null  int64
#  9   rank_2009    13156 non-null  int64
#  10  rank_2010    13156 non-null  int64
#  11  rank_2011    13156 non-null  int64
#  12  rank_2012    13156 non-null  int64
#  13  rank_2013    13156 non-null  int64
#  14  rank_2014    13156 non-null  int64
#  15  rank_2015    13156 non-null  int64
#  16  rank_2016    13156 non-null  int64
#  17  rank_2017    13156 non-null  int64
#  18  rank_2018    13156 non-null  int64
# ...

# %%
#find the shape of the data

pillars.shape
# Out:
# (13156, 40)

# %%
#remove duplicates
pillars.drop_duplicates()
# Out:
#         area_name  area_code area_group           pillar_name  rank_2004  \
# 0       Adair, IA      19001         IA            Governance        245
# 1       Adair, IA      19001         IA      Personal Freedom        351
# 2       Adair, IA      19001         IA   Safety and Security        121
# 3       Adair, IA      19001         IA        Social Capital        168
# 4       Adair, IA      19001         IA  Business Environment        833
# ...           ...        ...        ...                   ...        ...
# 13151  Zavala, TX      48507         TX        Infrastructure        955
# 13152  Zavala, TX      48507         TX             Education       1192
# 13153  Zavala, TX      48507         TX                Health        936
# 13154  Zavala, TX      48507         TX     Living Conditions       1187
# 13155  Zavala, TX      48507         TX   Natural Environment        439
#
#        rank_2005  rank_2006  rank_2007  rank_2008  rank_2009  ...  score_2012  \
# ...

# %%
#check the shape of data
pillars.shape
# Out:
# (13156, 40)

# %%
#export xls of Prosperity Table

prosperity = pillars.filter(['area_code','pillar_name','score_2021','rank_2021'], axis=1)

prosperity.head(5)
# Out:
#    area_code           pillar_name  score_2021  rank_2021
# 0      19001            Governance   69.239579        158
# 1      19001      Personal Freedom   61.070446        401
# 2      19001   Safety and Security   75.800424        348
# 3      19001        Social Capital   60.489680        255
# 4      19001  Business Environment   43.691604        704

# %%
#df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'}, inplace=True)

prosperity.rename(columns={'area_code': 'county_id', 'pillar_name':'metric'}, inplace=True)
prosperity.head(5)
# Out:
#    county_id                metric  score_2021  rank_2021
# 0      19001            Governance   69.239579        158
# 1      19001      Personal Freedom   61.070446        401
# 2      19001   Safety and Security   75.800424        348
# 3      19001        Social Capital   60.489680        255
# 4      19001  Business Environment   43.691604        704

# %%
#export to csv
prosperity.to_csv('Desktop/550/Prosperity.csv')

# %% [markdown]
# # Climate Data

# %% [markdown]
# Climate data came in 4 csv's. We're going to load each into a dataframe and then concatenate the dataframes

# %%
#getting the list of sheet names in the climate Excel file
cd = pd.read_csv('Desktop/550/1981-2010 Monthly (TX, MN, KY).csv')
cd.head(5)
# Out:
#        STATION            NAME  LATITUDE  LONGITUDE  ELEVATION  DATE  \
# 0  USC00412950  ESCOBAS, TX US  27.02667  -98.98083      125.0     1
# 1  USC00412950  ESCOBAS, TX US  27.02667  -98.98083      125.0     2
# 2  USC00412950  ESCOBAS, TX US  27.02667  -98.98083      125.0     3
# 3  USC00412950  ESCOBAS, TX US  27.02667  -98.98083      125.0     4
# 4  USC00412950  ESCOBAS, TX US  27.02667  -98.98083      125.0     5
#
#    MLY-DUTR-NORMAL MLY-DUTR-NORMAL_ATTRIBUTES  MLY-DUTR-STDDEV  \
# 0             22.1                          Q              NaN
# 1             23.8                          Q              NaN
# 2             23.3                          Q              NaN
# 3             22.9                          Q              NaN
# 4             21.4                          Q              NaN
#
#   MLY-DUTR-STDDEV_ATTRIBUTES  ...  MLY-TAVG-STDDEV MLY-TAVG-STDDEV_ATTRIBUTES  \
# 0                        NaN  ...              NaN                        NaN
# ...

# %%
cd1 = pd.read_csv('Desktop/550/1981-2010 Monthly (IA, GA, FL, OK).csv')
cd1.head(5)
# Out:
#        STATION          NAME  LATITUDE  LONGITUDE  ELEVATION  DATE  \
# 0  USC00349032  TUSSY, OK US  34.50111  -97.54333      291.7     1
# 1  USC00349032  TUSSY, OK US  34.50111  -97.54333      291.7     2
# 2  USC00349032  TUSSY, OK US  34.50111  -97.54333      291.7     3
# 3  USC00349032  TUSSY, OK US  34.50111  -97.54333      291.7     4
# 4  USC00349032  TUSSY, OK US  34.50111  -97.54333      291.7     5
#
#    MLY-DUTR-NORMAL MLY-DUTR-NORMAL_ATTRIBUTES  MLY-DUTR-STDDEV  \
# 0              NaN                        NaN              NaN
# 1              NaN                        NaN              NaN
# 2              NaN                        NaN              NaN
# 3              NaN                        NaN              NaN
# 4              NaN                        NaN              NaN
#
#   MLY-DUTR-STDDEV_ATTRIBUTES  ...  MLY-TAVG-STDDEV MLY-TAVG-STDDEV_ATTRIBUTES  \
# 0                        NaN  ...              NaN                        NaN
# ...

# %%
cd2 = pd.read_csv('Desktop/550/1981-2010 Monthly (CO, MT, NY, NE).csv')
cd2.head(5)
# Out:
#        STATION                NAME  LATITUDE  LONGITUDE  ELEVATION  DATE  \
# 0  USC00247128  ROBERTS 1 W, MT US   45.3573  -109.1884     1417.3     1
# 1  USC00247128  ROBERTS 1 W, MT US   45.3573  -109.1884     1417.3     2
# 2  USC00247128  ROBERTS 1 W, MT US   45.3573  -109.1884     1417.3     3
# 3  USC00247128  ROBERTS 1 W, MT US   45.3573  -109.1884     1417.3     4
# 4  USC00247128  ROBERTS 1 W, MT US   45.3573  -109.1884     1417.3     5
#
#    MLY-DUTR-NORMAL MLY-DUTR-NORMAL_ATTRIBUTES  MLY-DUTR-STDDEV  \
# 0              NaN                        NaN              NaN
# 1              NaN                        NaN              NaN
# 2              NaN                        NaN              NaN
# 3              NaN                        NaN              NaN
# 4              NaN                        NaN              NaN
#
#   MLY-DUTR-STDDEV_ATTRIBUTES  ...  MLY-TAVG-STDDEV MLY-TAVG-STDDEV_ATTRIBUTES  \
# ...

# %%
cd3 = pd.read_csv('Desktop/550/1981-2010 Monthly (CA).csv')
cd3.head(5)
# Out:
#        STATION                     NAME  LATITUDE  LONGITUDE  ELEVATION  DATE  \
# 0  USC00049099  TWENTYNINE PALMS, CA US    34.128  -116.0369      602.0     1
# 1  USC00049099  TWENTYNINE PALMS, CA US    34.128  -116.0369      602.0     2
# 2  USC00049099  TWENTYNINE PALMS, CA US    34.128  -116.0369      602.0     3
# 3  USC00049099  TWENTYNINE PALMS, CA US    34.128  -116.0369      602.0     4
# 4  USC00049099  TWENTYNINE PALMS, CA US    34.128  -116.0369      602.0     5
#
#    MLY-DUTR-NORMAL MLY-DUTR-NORMAL_ATTRIBUTES  MLY-DUTR-STDDEV  \
# 0             20.6                          R              2.9
# 1             21.9                          R              3.2
# 2             24.1                          R              2.9
# 3             26.0                          R              1.9
# 4             26.7                          R              1.7
#
#   MLY-DUTR-STDDEV_ATTRIBUTES  ...  MLY-TAVG-STDDEV MLY-TAVG-STDDEV_ATTRIBUTES  \
# ...

# %%
#concatenate all for dataframes
climate = pd.concat([cd, cd1, cd2, cd3])
climate.head(5)
# Out:
#        STATION            NAME  LATITUDE  LONGITUDE  ELEVATION  DATE  \
# 0  USC00412950  ESCOBAS, TX US  27.02667  -98.98083      125.0     1
# 1  USC00412950  ESCOBAS, TX US  27.02667  -98.98083      125.0     2
# 2  USC00412950  ESCOBAS, TX US  27.02667  -98.98083      125.0     3
# 3  USC00412950  ESCOBAS, TX US  27.02667  -98.98083      125.0     4
# 4  USC00412950  ESCOBAS, TX US  27.02667  -98.98083      125.0     5
#
#    MLY-DUTR-NORMAL MLY-DUTR-NORMAL_ATTRIBUTES  MLY-DUTR-STDDEV  \
# 0             22.1                          Q              NaN
# 1             23.8                          Q              NaN
# 2             23.3                          Q              NaN
# 3             22.9                          Q              NaN
# 4             21.4                          Q              NaN
#
#   MLY-DUTR-STDDEV_ATTRIBUTES  ...  MLY-TAVG-STDDEV MLY-TAVG-STDDEV_ATTRIBUTES  \
# 0                        NaN  ...              NaN                        NaN
# ...

# %%
#doing a little sanity check to make sure it loaded as we expected
climate.loc[climate.STATION=='USC00040010']
# Out:
#           STATION                NAME  LATITUDE  LONGITUDE  ELEVATION  DATE  \
# 2460  USC00040010  ACAMPO 5 NE, CA US   38.2177  -121.2013       26.5     1
# 2461  USC00040010  ACAMPO 5 NE, CA US   38.2177  -121.2013       26.5     2
# 2462  USC00040010  ACAMPO 5 NE, CA US   38.2177  -121.2013       26.5     3
# 2463  USC00040010  ACAMPO 5 NE, CA US   38.2177  -121.2013       26.5     4
# 2464  USC00040010  ACAMPO 5 NE, CA US   38.2177  -121.2013       26.5     5
# 2465  USC00040010  ACAMPO 5 NE, CA US   38.2177  -121.2013       26.5     6
# 2466  USC00040010  ACAMPO 5 NE, CA US   38.2177  -121.2013       26.5     7
# 2467  USC00040010  ACAMPO 5 NE, CA US   38.2177  -121.2013       26.5     8
# 2468  USC00040010  ACAMPO 5 NE, CA US   38.2177  -121.2013       26.5     9
# 2469  USC00040010  ACAMPO 5 NE, CA US   38.2177  -121.2013       26.5    10
# 2470  USC00040010  ACAMPO 5 NE, CA US   38.2177  -121.2013       26.5    11
# ...

# %%
climate.shape
# Out:
# (35628, 30)

# %%
climate.describe()
# Out:
#            LATITUDE     LONGITUDE     ELEVATION          DATE  \
# count  35628.000000  35628.000000  35628.000000  35628.000000
# mean      37.696136    -98.900751    557.579151      6.500000
# std        5.854273     12.505830    592.713821      3.452101
# min       24.555000   -124.236670    -59.100000      1.000000
# 25%       33.053700   -106.127600    146.300000      3.750000
# 50%       37.751200    -97.956300    340.800000      6.500000
# 75%       42.109440    -92.646600    806.200000      9.250000
# max       48.999200    -71.923330   3457.700000     12.000000
#
#        MLY-DUTR-NORMAL  MLY-DUTR-STDDEV  MLY-PRCP-AVGNDS-GE001HI  \
# count     27960.000000     23388.000000             27192.000000
# mean         23.995869         2.783590                 3.319723
# std           5.338408         0.785502               170.192100
# min           6.500000         0.400000             -7777.000000
# 25%          20.600000         2.200000                 4.900000
# ...

# %%
climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35628 entries, 0 to 5087
# Data columns (total 30 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   STATION                             35628 non-null  object
#  1   NAME                                35628 non-null  object
#  2   LATITUDE                            35628 non-null  float64
#  3   LONGITUDE                           35628 non-null  float64
#  4   ELEVATION                           35628 non-null  float64
#  5   DATE                                35628 non-null  int64
#  6   MLY-DUTR-NORMAL                     27960 non-null  float64
#  7   MLY-DUTR-NORMAL_ATTRIBUTES          27960 non-null  object
#  8   MLY-DUTR-STDDEV                     23388 non-null  float64
#  9   MLY-DUTR-STDDEV_ATTRIBUTES          23388 non-null  object
#  10  MLY-PRCP-AVGNDS-GE001HI             27192 non-null  float64
# ...

# %%
list(climate.columns)
# Out:
# ['STATION',
#  'NAME',
#  'LATITUDE',
#  'LONGITUDE',
#  'ELEVATION',
#  'DATE',
#  'MLY-DUTR-NORMAL',
#  'MLY-DUTR-NORMAL_ATTRIBUTES',
#  'MLY-DUTR-STDDEV',
#  'MLY-DUTR-STDDEV_ATTRIBUTES',
#  'MLY-PRCP-AVGNDS-GE001HI',
#  'MLY-PRCP-AVGNDS-GE001HI_ATTRIBUTES',
#  'MLY-PRCP-NORMAL',
#  'MLY-PRCP-NORMAL_ATTRIBUTES',
#  'MLY-SNOW-AVGNDS-GE001TI',
#  'MLY-SNOW-AVGNDS-GE001TI_ATTRIBUTES',
#  'MLY-SNOW-NORMAL',
#  'MLY-SNOW-NORMAL_ATTRIBUTES',
#  'MLY-TAVG-NORMAL',
#  'MLY-TAVG-NORMAL_ATTRIBUTES',
#  'MLY-TAVG-STDDEV',
#  'MLY-TAVG-STDDEV_ATTRIBUTES',
#  'MLY-TMAX-NORMAL',
#  'MLY-TMAX-NORMAL_ATTRIBUTES',
#  'MLY-TMAX-STDDEV',
#  'MLY-TMAX-STDDEV_ATTRIBUTES',
#  'MLY-TMIN-NORMAL',
#  'MLY-TMIN-NORMAL_ATTRIBUTES',
#  'MLY-TMIN-STDDEV',
#  'MLY-TMIN-STDDEV_ATTRIBUTES']

# %%
#what columns are culprits for nulls
climate.isnull().any()
# Out:
# STATION                               False
# NAME                                  False
# LATITUDE                              False
# LONGITUDE                             False
# ELEVATION                             False
# DATE                                  False
# MLY-DUTR-NORMAL                        True
# MLY-DUTR-NORMAL_ATTRIBUTES             True
# MLY-DUTR-STDDEV                        True
# MLY-DUTR-STDDEV_ATTRIBUTES             True
# MLY-PRCP-AVGNDS-GE001HI                True
# MLY-PRCP-AVGNDS-GE001HI_ATTRIBUTES     True
# MLY-PRCP-NORMAL                        True
# MLY-PRCP-NORMAL_ATTRIBUTES             True
# MLY-SNOW-AVGNDS-GE001TI                True
# MLY-SNOW-AVGNDS-GE001TI_ATTRIBUTES     True
# MLY-SNOW-NORMAL                        True
# MLY-SNOW-NORMAL_ATTRIBUTES             True
# MLY-TAVG-NORMAL                        True
# MLY-TAVG-NORMAL_ATTRIBUTES             True
# MLY-TAVG-STDDEV                        True
# ...

# %%
#The percentage of null values per column
climate.isnull().sum() / climate.shape[0] * 100.00
# Out:
# STATION                                0.000000
# NAME                                   0.000000
# LATITUDE                               0.000000
# LONGITUDE                              0.000000
# ELEVATION                              0.000000
# DATE                                   0.000000
# MLY-DUTR-NORMAL                       21.522398
# MLY-DUTR-NORMAL_ATTRIBUTES            21.522398
# MLY-DUTR-STDDEV                       34.355002
# MLY-DUTR-STDDEV_ATTRIBUTES            34.355002
# MLY-PRCP-AVGNDS-GE001HI               23.678006
# MLY-PRCP-AVGNDS-GE001HI_ATTRIBUTES    23.678006
# MLY-PRCP-NORMAL                        3.267093
# MLY-PRCP-NORMAL_ATTRIBUTES             3.267093
# MLY-SNOW-AVGNDS-GE001TI               33.142472
# MLY-SNOW-AVGNDS-GE001TI_ATTRIBUTES    33.142472
# MLY-SNOW-NORMAL                       33.142472
# MLY-SNOW-NORMAL_ATTRIBUTES            33.142472
# MLY-TAVG-NORMAL                       21.522398
# MLY-TAVG-NORMAL_ATTRIBUTES            21.522398
# ...

# %%
# We decided not to drop any nulls but instead, for the fields we need, change any nulls to -1.
# We chose not to go with 0 to distinguish actual 0 values

# %%
######EDIT- CHANGE TO " " (empty string) to distringuish from actual 0 values.########
climate['MLY-PRCP-NORMAL'] = climate['MLY-PRCP-NORMAL'].fillna("")
climate['MLY-SNOW-NORMAL'] = climate['MLY-SNOW-NORMAL'].fillna("")
climate['MLY-TAVG-NORMAL'] = climate['MLY-TAVG-NORMAL'].fillna("")
climate['MLY-TMAX-NORMAL'] = climate['MLY-TMAX-NORMAL'].fillna("")
climate['MLY-TMIN-NORMAL'] = climate['MLY-TMIN-NORMAL'].fillna("")
climate.isnull().any()
# Out:
# STATION                               False
# NAME                                  False
# LATITUDE                              False
# LONGITUDE                             False
# ELEVATION                             False
# DATE                                  False
# MLY-DUTR-NORMAL                        True
# MLY-DUTR-NORMAL_ATTRIBUTES             True
# MLY-DUTR-STDDEV                        True
# MLY-DUTR-STDDEV_ATTRIBUTES             True
# MLY-PRCP-AVGNDS-GE001HI                True
# MLY-PRCP-AVGNDS-GE001HI_ATTRIBUTES     True
# MLY-PRCP-NORMAL                       False
# MLY-PRCP-NORMAL_ATTRIBUTES             True
# MLY-SNOW-AVGNDS-GE001TI                True
# MLY-SNOW-AVGNDS-GE001TI_ATTRIBUTES     True
# MLY-SNOW-NORMAL                       False
# MLY-SNOW-NORMAL_ATTRIBUTES             True
# MLY-TAVG-NORMAL                       False
# MLY-TAVG-NORMAL_ATTRIBUTES             True
# MLY-TAVG-STDDEV                        True
# ...

# %%
#drop duplicates
climate.drop_duplicates()
# Out:
#           STATION                     NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0     USC00412950           ESCOBAS, TX US  27.02667  -98.98083      125.0
# 1     USC00412950           ESCOBAS, TX US  27.02667  -98.98083      125.0
# 2     USC00412950           ESCOBAS, TX US  27.02667  -98.98083      125.0
# 3     USC00412950           ESCOBAS, TX US  27.02667  -98.98083      125.0
# 4     USC00412950           ESCOBAS, TX US  27.02667  -98.98083      125.0
# ...           ...                      ...       ...        ...        ...
# 5083  USC00046006  MOUNT WILSON CBS, CA US  34.23080 -118.07110     1740.4
# 5084  USC00046006  MOUNT WILSON CBS, CA US  34.23080 -118.07110     1740.4
# 5085  USC00046006  MOUNT WILSON CBS, CA US  34.23080 -118.07110     1740.4
# 5086  USC00046006  MOUNT WILSON CBS, CA US  34.23080 -118.07110     1740.4
# 5087  USC00046006  MOUNT WILSON CBS, CA US  34.23080 -118.07110     1740.4
#
# ...

# %%
#filter out the fields we need

climates = climate.filter(['STATION','LATITUDE','NAME', 'LONGITUDE','DATE', 'MLY-TAVG-NORMAL', 'MLY-TMIN-NORMAL', 'MLY-TMAX-NORMAL','MLY-PRCP-NORMAL','MLY-SNOW-NORMAL' ], axis=1)
climates.head(5)
# Out:
#        STATION  LATITUDE            NAME  LONGITUDE  DATE MLY-TAVG-NORMAL  \
# 0  USC00412950  27.02667  ESCOBAS, TX US  -98.98083     1            56.5
# 1  USC00412950  27.02667  ESCOBAS, TX US  -98.98083     2            60.3
# 2  USC00412950  27.02667  ESCOBAS, TX US  -98.98083     3            68.1
# 3  USC00412950  27.02667  ESCOBAS, TX US  -98.98083     4            74.6
# 4  USC00412950  27.02667  ESCOBAS, TX US  -98.98083     5            80.5
#
#   MLY-TMIN-NORMAL MLY-TMAX-NORMAL MLY-PRCP-NORMAL MLY-SNOW-NORMAL
# 0            45.4            67.5            1.09
# 1            48.4            72.2            1.23
# 2            56.4            79.7             0.9
# 3            63.1            86.0            1.29
# 4            69.8            91.2            2.19

# %% [markdown]
# Time to check fields for special values and then remove them

# %% [markdown]
# ### Monthly Average

# %%
#check every field for special values: -9999, -7777, -6666, -4444

nine = climates[climates['MLY-TAVG-NORMAL'] == -9999]
nine.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %%
seven = climates[climates['MLY-TAVG-NORMAL'] == -7777]
seven.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %%
six = climates[climates['MLY-TAVG-NORMAL'] == -6666]
six.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %%
four = climates[climates['MLY-TAVG-NORMAL'] == -4444]
four.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %% [markdown]
# No special characters in Average Temperature

# %% [markdown]
# ### Min Temperature

# %%
#check every field for special values: -9999, -7777, -6666, -4444

nine1 = climates[climates['MLY-TMIN-NORMAL'] == -9999]
nine1.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %%
seven1 = climates[climates['MLY-TMIN-NORMAL'] == -7777]
seven1.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %%
six1 = climates[climates['MLY-TMIN-NORMAL'] == -6666]
six1.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %%
four1 = climates[climates['MLY-TMIN-NORMAL'] == -4444]
four1.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %% [markdown]
# No special characters in Min Temperature

# %% [markdown]
# ### Max Temperature

# %%
#check every field for special values: -9999, -7777, -6666, -4444

nine2 = climates[climates['MLY-TMAX-NORMAL'] == -9999]
nine2.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %%
seven2 = climates[climates['MLY-TMAX-NORMAL'] == -7777]
seven2.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %%
six2 = climates[climates['MLY-TMAX-NORMAL'] == -6666]
six2.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %%
four2 = climates[climates['MLY-TMAX-NORMAL'] == -4444]
four2.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %% [markdown]
# No special characters in Max Temperature

# %% [markdown]
# ### Rain

# %%
#check every field for special values: -9999, -7777, -6666, -4444

nine3 = climates[climates['MLY-PRCP-NORMAL'] == -9999]
nine3.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %%
seven3 = climates[climates['MLY-PRCP-NORMAL'] == -7777]
seven3.head(5)
# Out:
#          STATION  LATITUDE                                  NAME  LONGITUDE  \
# 66   USC00044997   37.6922                      LIVERMORE, CA US -121.76910
# 150  USC00042346   35.7683                         DELANO, CA US -119.26000
# 366  USW00093209   35.6697  PASO ROBLES MUNICIPAL AIRPORT, CA US -120.62830
# 786  USC00046610   36.7150                   PAICINES 4 W, CA US -121.34917
# 798  USC00042012   36.0975      CORCORAN IRRIGATION DIST., CA US -119.58170
#
#      DATE MLY-TAVG-NORMAL MLY-TMIN-NORMAL MLY-TMAX-NORMAL MLY-PRCP-NORMAL  \
# 66      7            72.8            56.8            88.9         -7777.0
# 150     7                                                         -7777.0
# 366     7            73.4            54.1            92.8         -7777.0
# 786     7            67.9            48.7            87.0         -7777.0
# 798     7            80.5            62.9            98.1         -7777.0
#
#     MLY-SNOW-NORMAL
# 66              0.0
# 150             0.0
# ...

# %% [markdown]
# We have special characters and we need to decide what to do with them.
# According to documentation -7777 is a non-zero value that would round to 0. In this case, let's replace with 0.

# %%
climates = climates.replace({'MLY-PRCP-NORMAL':-7777.0},0.0)
seven31 = climates[climates['MLY-PRCP-NORMAL'] == -7777]
seven31.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %% [markdown]
# values have been replaced

# %%
#double checking that they have been replaced
seven3 = climates[climates['MLY-PRCP-NORMAL'] == -7777]
seven3.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %%
six3 = climates[climates['MLY-PRCP-NORMAL'] == -6666]
six3.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %%
four3 = climates[climates['MLY-PRCP-NORMAL'] == -4444]
four3.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %% [markdown]
# ### Snow

# %%
#check every field for special values: -9999, -7777, -6666, -4444

nine4 = climates[climates['MLY-SNOW-NORMAL'] == -9999]
nine4.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %%
seven4 = climates[climates['MLY-SNOW-NORMAL'] == -7777]
seven4.head(5)
# Out:
#         STATION  LATITUDE                   NAME  LONGITUDE  DATE  \
# 14  USW00003951  32.34660  LONGVIEW 11 SE, TX US   -94.6533     3
# 22  USW00003951  32.34660  LONGVIEW 11 SE, TX US   -94.6533    11
# 38  USC00410779  31.20010      BIG LAKE 2, TX US  -101.4626     3
# 51  USC00411625  32.15610  CHALK MOUNTAIN, TX US   -97.9369     4
# 62  USC00412715  32.39889        EASTLAND, TX US   -98.8175     3
#
#    MLY-TAVG-NORMAL MLY-TMIN-NORMAL MLY-TMAX-NORMAL MLY-PRCP-NORMAL  \
# 14            58.0            47.4            68.7            4.45
# 22            57.1            46.8            67.4            4.77
# 38            56.0            42.1            69.9            1.29
# 51                                                            2.89
# 62            54.4            40.4            68.4            2.57
#
#    MLY-SNOW-NORMAL
# 14         -7777.0
# 22         -7777.0
# 38         -7777.0
# 51         -7777.0
# 62         -7777.0

# %%
#get rid of -7777 values

# %%
climates = climates.replace({'MLY-SNOW-NORMAL':-7777.0},0.0)

# %%
six4 = climates[climates['MLY-SNOW-NORMAL'] == -6666]
six4.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %%
four4 = climates[climates['MLY-SNOW-NORMAL'] == -4444]
four4.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %% [markdown]
# Replace the -4444 in snow. -4444 represents a year round risk of frost-freeze, so it doesn't make sense to replace with 0. So maybe setting this to be above average so skew towards a more snow-heavy place.

# %%
climates = climates.replace({'MLY-SNOW-NORMAL':-4444.0},60.0)
fours41 = climates[climates['MLY-SNOW-NORMAL'] == -4444]
fours41.head(5)
# Out:
# Empty DataFrame
# Columns: [STATION, LATITUDE, NAME, LONGITUDE, DATE, MLY-TAVG-NORMAL, MLY-TMIN-NORMAL, MLY-TMAX-NORMAL, MLY-PRCP-NORMAL, MLY-SNOW-NORMAL]
# Index: []

# %% [markdown]
# Values have been replaced

# %% [markdown]
# #### Climate export

# %%
climates.rename(columns={'STATION': 'station_id', 'LATITUDE': 'latitude','LONGITUDE': 'longitude', 'DATE':'month', 'MLY-TAVG-NORMAL':'temp_avg','MLY-TMIN-NORMAL':'temp_min','MLY-TMAX-NORMAL':'temp_max', 'MLY-PRCP-NORMAL':'rain_days','MLY-SNOW-NORMAL':'snow_days'
 }, inplace=True)
climates.head(5)
# Out:
#     station_id  latitude            NAME  longitude  month temp_avg temp_min  \
# 0  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      1     56.5     45.4
# 1  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      2     60.3     48.4
# 2  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      3     68.1     56.4
# 3  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      4     74.6     63.1
# 4  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      5     80.5     69.8
#
#   temp_max rain_days snow_days
# 0     67.5      1.09
# 1     72.2      1.23
# 2     79.7       0.9
# 3     86.0      1.29
# 4     91.2      2.19

# %%
climates.to_csv('Desktop/550/Climate.csv')

# %% [markdown]
# ## US Zips

# %%
zips = pd.read_csv('Desktop/550/uszips.csv')
zips.tail(5)
# Out:
#          zip       lat        lng         city state_id state_name  zcta  \
# 33115  99923  55.97796 -130.03671        Hyder       AK     Alaska  True
# 33116  99925  55.55796 -132.97482      Klawock       AK     Alaska  True
# 33117  99926  55.12617 -131.48928   Metlakatla       AK     Alaska  True
# 33118  99927  56.25100 -133.37572  Point Baker       AK     Alaska  True
# 33119  99929  56.36950 -131.93648     Wrangell       AK     Alaska  True
#
#        parent_zcta  population  density  county_fips            county_name  \
# 33115          NaN        14.0      0.3         2198  Prince of Wales-Hyder
# 33116          NaN       908.0      6.3         2198  Prince of Wales-Hyder
# 33117          NaN      1654.0      4.8         2198  Prince of Wales-Hyder
# 33118          NaN         0.0      0.0         2198  Prince of Wales-Hyder
# 33119          NaN      2502.0      0.4         2275               Wrangell
#
# ...

# %%
zips.shape
# Out:
# (33120, 18)

# %%
zips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33120 entries, 0 to 33119
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   zip               33120 non-null  int64
#  1   lat               33120 non-null  float64
#  2   lng               33120 non-null  float64
#  3   city              33120 non-null  object
#  4   state_id          33120 non-null  object
#  5   state_name        33120 non-null  object
#  6   zcta              33120 non-null  bool
#  7   parent_zcta       0 non-null      float64
#  8   population        33096 non-null  float64
#  9   density           33096 non-null  float64
#  10  county_fips       33120 non-null  int64
#  11  county_name       33120 non-null  object
#  12  county_weights    33120 non-null  object
#  13  county_names_all  33120 non-null  object
#  14  county_fips_all   33120 non-null  object
#  15  imprecise         33120 non-null  bool
# ...

# %%
zips.describe()
# Out:
#                 zip           lat           lng  parent_zcta     population  \
# count  33120.000000  33120.000000  33120.000000          0.0   33096.000000
# mean   49663.358182     38.818320    -90.921367          NaN    9909.878293
# std    27585.173649      5.398053     15.787010          NaN   14717.143962
# min      601.000000    -14.219670   -176.631380          NaN       0.000000
# 25%    26618.500000     35.389820    -97.233710          NaN     707.000000
# 50%    49739.000000     39.494475    -88.188120          NaN    2804.500000
# 75%    72130.250000     42.119927    -80.216425          NaN   13481.000000
# max    99929.000000     71.273760    145.753560          NaN  128294.000000
#
#             density   county_fips
# count  33096.000000  33120.000000
# mean     509.735400  30007.718539
# std     1974.357547  15503.079107
# min        0.000000   1001.000000
# 25%        7.600000  18061.000000
# 50%       30.500000  30027.000000
# 75%      265.150000  42057.000000
# ...

# %%
#There are null values. Let's check them out and then get rid of them
zips.isnull().any()
# Out:
# zip                 False
# lat                 False
# lng                 False
# city                False
# state_id            False
# state_name          False
# zcta                False
# parent_zcta          True
# population           True
# density              True
# county_fips         False
# county_name         False
# county_weights      False
# county_names_all    False
# county_fips_all     False
# imprecise           False
# military            False
# timezone            False
# dtype: bool

# %%
#The percentage of null values per column
zips.isnull().sum() / zips.shape[0] * 100.00
# Out:
# zip                   0.000000
# lat                   0.000000
# lng                   0.000000
# city                  0.000000
# state_id              0.000000
# state_name            0.000000
# zcta                  0.000000
# parent_zcta         100.000000
# population            0.072464
# density               0.072464
# county_fips           0.000000
# county_name           0.000000
# county_weights        0.000000
# county_names_all      0.000000
# county_fips_all       0.000000
# imprecise             0.000000
# military              0.000000
# timezone              0.000000
# dtype: float64

# %%
#we can drop the parent zcta field and also the rows that are null as they are such a small percentage of the dataset
zips=zips.drop(columns=(['parent_zcta']))

# %%
zips.head(5)
# Out:
#    zip       lat       lng       city state_id   state_name  zcta  population  \
# 0  601  18.18005 -66.75218   Adjuntas       PR  Puerto Rico  True     17113.0
# 1  602  18.36074 -67.17519     Aguada       PR  Puerto Rico  True     37751.0
# 2  603  18.45440 -67.12201  Aguadilla       PR  Puerto Rico  True     47081.0
# 3  606  18.16721 -66.93828    Maricao       PR  Puerto Rico  True      6392.0
# 4  610  18.29032 -67.12244     Anasco       PR  Puerto Rico  True     26686.0
#
#    density  county_fips county_name  \
# 0    102.7        72001    Adjuntas
# 1    476.0        72003      Aguada
# 2    574.9        72005   Aguadilla
# 3     58.3        72093     Maricao
# 4    286.9        72011      Añasco
#
#                                       county_weights  \
# 0                {"72001": "99.43", "72141": "0.57"}
# 1                                   {"72003": "100"}
# 2                                   {"72005": "100"}
# 3  {"72093": "94.88", "72153": "3.78", "72121": "...
# ...

# %%
#drop tuples with na sicne it's a small percentage
zips=zips.dropna(axis=0)
zips.isnull().any()
# Out:
# zip                 False
# lat                 False
# lng                 False
# city                False
# state_id            False
# state_name          False
# zcta                False
# population          False
# density             False
# county_fips         False
# county_name         False
# county_weights      False
# county_names_all    False
# county_fips_all     False
# imprecise           False
# military            False
# timezone            False
# dtype: bool

# %%
zips = zips.drop_duplicates()
zips.tail(20)
# Out:
#          zip       lat        lng             city state_id state_name  zcta  \
# 33100  99827  59.12421 -135.70688           Haines       AK     Alaska  True
# 33101  99829  58.10738 -135.42585           Hoonah       AK     Alaska  True
# 33102  99830  56.77903 -134.16029             Kake       AK     Alaska  True
# 33103  99832  58.01535 -136.17832          Pelican       AK     Alaska  True
# 33104  99833  56.88523 -133.08513       Petersburg       AK     Alaska  True
# 33105  99835  56.96056 -135.05446            Sitka       AK     Alaska  True
# 33106  99836  56.23548 -134.65335   Port Alexander       AK     Alaska  True
# 33107  99840  59.56292 -135.33619          Skagway       AK     Alaska  True
# 33108  99841  57.79433 -135.18486  Tenakee Springs       AK     Alaska  True
# 33109  99901  55.56908 -131.01273        Ketchikan       AK     Alaska  True
# 33110  99903  55.82123 -132.05943     Meyers Chuck       AK     Alaska  True
# ...

# %%
#sanity check for unique county names
zips['county_names_all'].unique()
# Out:
# array(['Adjuntas|Utuado', 'Aguada', 'Aguadilla', ...,
#        'Ketchikan Gateway|Prince of Wales-Hyder', 'Wrangell',
#        'Prince of Wales-Hyder'], dtype=object)

# %%
#split county names based on pipes. Put the county name in a column of its own so that we pick one county only

columns = list(zips.county_names_all)
vals = []

for col in columns:
 
  #split based on pipe
  c = col.split("|")
  vals.append(c[0])
 
#vals to be able to add the county to dataframe
zips['one_county'] = vals
zips.head(10)
# Out:
#    zip       lat       lng         city state_id   state_name  zcta  \
# 0  601  18.18005 -66.75218     Adjuntas       PR  Puerto Rico  True
# 1  602  18.36074 -67.17519       Aguada       PR  Puerto Rico  True
# 2  603  18.45440 -67.12201    Aguadilla       PR  Puerto Rico  True
# 3  606  18.16721 -66.93828      Maricao       PR  Puerto Rico  True
# 4  610  18.29032 -67.12244       Anasco       PR  Puerto Rico  True
# 5  612  18.40699 -66.70805      Arecibo       PR  Puerto Rico  True
# 6  616  18.41752 -66.66814     Bajadero       PR  Puerto Rico  True
# 7  617  18.44125 -66.55916  Barceloneta       PR  Puerto Rico  True
# 8  622  17.99174 -67.15248     Boqueron       PR  Puerto Rico  True
# 9  623  18.08354 -67.15418    Cabo Rojo       PR  Puerto Rico  True
#
#    population  density  county_fips  county_name  \
# 0     17113.0    102.7        72001     Adjuntas
# 1     37751.0    476.0        72003       Aguada
# 2     47081.0    574.9        72005    Aguadilla
# ...

# %%
#Do the same for Fips. We'll pick one fips code only from fields with multiple fips.

columns2 = list(zips.county_fips_all)
vals2 = []

for col in columns2:
 
  #split based on pipe
  c2 = col.split("|")
  vals2.append(c2[0])
  
#vals
zips['one_fips'] = vals2
zips.head(10)
# Out:
#    zip       lat       lng         city state_id   state_name  zcta  \
# 0  601  18.18005 -66.75218     Adjuntas       PR  Puerto Rico  True
# 1  602  18.36074 -67.17519       Aguada       PR  Puerto Rico  True
# 2  603  18.45440 -67.12201    Aguadilla       PR  Puerto Rico  True
# 3  606  18.16721 -66.93828      Maricao       PR  Puerto Rico  True
# 4  610  18.29032 -67.12244       Anasco       PR  Puerto Rico  True
# 5  612  18.40699 -66.70805      Arecibo       PR  Puerto Rico  True
# 6  616  18.41752 -66.66814     Bajadero       PR  Puerto Rico  True
# 7  617  18.44125 -66.55916  Barceloneta       PR  Puerto Rico  True
# 8  622  17.99174 -67.15248     Boqueron       PR  Puerto Rico  True
# 9  623  18.08354 -67.15418    Cabo Rojo       PR  Puerto Rico  True
#
#    population  density  county_fips  county_name  \
# 0     17113.0    102.7        72001     Adjuntas
# 1     37751.0    476.0        72003       Aguada
# 2     47081.0    574.9        72005    Aguadilla
# ...

# %%
#need to check if one_county and one_zip is the same as county_fips and county_name

# %%
#we can now drop all the columns we don't need and export to file
#also note that one side effect of is that we now have all fips with the 0 in front
#colums, I recommend dropping include:
#zcta, population, density, county_fips	county_name	county_weights	county_names_all	county_fips_all	imprecise	military

zips.tail(10)
# Out:
#          zip       lat        lng          city state_id state_name  zcta  \
# 33110  99903  55.82123 -132.05943  Meyers Chuck       AK     Alaska  True
# 33111  99918  55.94572 -132.74165  Coffman Cove       AK     Alaska  True
# 33112  99919  55.65107 -132.50367    Thorne Bay       AK     Alaska  True
# 33113  99921  55.45483 -132.77225         Craig       AK     Alaska  True
# 33114  99922  55.30211 -133.03248      Hydaburg       AK     Alaska  True
# 33115  99923  55.97796 -130.03671         Hyder       AK     Alaska  True
# 33116  99925  55.55796 -132.97482       Klawock       AK     Alaska  True
# 33117  99926  55.12617 -131.48928    Metlakatla       AK     Alaska  True
# 33118  99927  56.25100 -133.37572   Point Baker       AK     Alaska  True
# 33119  99929  56.36950 -131.93648      Wrangell       AK     Alaska  True
#
#        population  density  county_fips            county_name  \
# 33110         0.0      0.0         2275               Wrangell
# ...

# %% [markdown]
# ## Counties

# %%
counties = zips.filter(['one_fips', 'one_county','state_id'], axis=1)
counties.head(5)
# Out:
#   one_fips one_county state_id
# 0    72001   Adjuntas       PR
# 1    72003     Aguada       PR
# 2    72005  Aguadilla       PR
# 3    72093    Maricao       PR
# 4    72011     Añasco       PR

# %%
counties.rename(columns={'one_fips': 'fips_code', 'one_county':'name'}, inplace=True)
counties.head(5)
# Out:
#   fips_code       name state_id
# 0     72001   Adjuntas       PR
# 1     72003     Aguada       PR
# 2     72005  Aguadilla       PR
# 3     72093    Maricao       PR
# 4     72011     Añasco       PR

# %%
#export to csv
counties.to_csv('Desktop/550/Counties.csv')

# %% [markdown]
# ## Districts

# %%
districts = zips.filter(['zip', 'lat', 'lng','population','density','one_fips', 'city'], axis=1)
districts.head(5)
# Out:
#    zip       lat       lng  population  density one_fips       city
# 0  601  18.18005 -66.75218     17113.0    102.7    72001   Adjuntas
# 1  602  18.36074 -67.17519     37751.0    476.0    72003     Aguada
# 2  603  18.45440 -67.12201     47081.0    574.9    72005  Aguadilla
# 3  606  18.16721 -66.93828      6392.0     58.3    72093    Maricao
# 4  610  18.29032 -67.12244     26686.0    286.9    72011     Anasco

# %%
districts.rename(columns={'lat': 'latitude', 'lng':'longitude', 'density':'pop_density', 'one_fips': 'county_id'}, inplace=True)
districts.head(5)
# Out:
#    zip  latitude  longitude  population  pop_density county_id       city
# 0  601  18.18005  -66.75218     17113.0        102.7     72001   Adjuntas
# 1  602  18.36074  -67.17519     37751.0        476.0     72003     Aguada
# 2  603  18.45440  -67.12201     47081.0        574.9     72005  Aguadilla
# 3  606  18.16721  -66.93828      6392.0         58.3     72093    Maricao
# 4  610  18.29032  -67.12244     26686.0        286.9     72011     Anasco

# %%
districts.to_csv('Desktop/550/Districts.csv')

# %% [markdown]
# ## Weather Stations

# %%
#We have to import package that allow us to do reverse geocoding to be able to tie our fips
#code to coodinates or station id

# %%
# %pip install ipython-autotime
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install geopandas

# %%
# !pip install plotly_express

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#trying reverse geocoding

# %load_ext autotime
import numpy as np
import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import matplotlib.pyplot as plt
import plotly_express as px
import tqdm
from tqdm._tqdm_notebook import tqdm_notebook
# Out:
# time: 848 ms (started: 2022-04-17 12:57:38 -05:00)
# /var/folders/px/1q66z5cs7tzdf7gns632xbv40000gn/T/ipykernel_21790/1376840479.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   from tqdm._tqdm_notebook import tqdm_notebook

# %%
#testing that reverse geocoder works
locator = Nominatim(user_agent="google")
coordinates = "38.241416,-121.2013"
location = locator.reverse(coordinates)
# Out:
# time: 345 ms (started: 2022-04-17 12:57:39 -05:00)

# %%
#verifying the information the geocoder outputs
location.raw
# Out:
# {'place_id': 235046549,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 673441738,
#  'lat': '38.241627644477425',
#  'lon': '-121.20130304075971',
#  'display_name': 'East Cattani Lane, San Joaquin County, California, United States',
#  'address': {'road': 'East Cattani Lane',
#   'county': 'San Joaquin County',
#   'state': 'California',
#   'ISO3166-2-lvl4': 'US-CA',
#   'country': 'United States',
#   'country_code': 'us'},
#  'boundingbox': ['38.2415887', '38.2416582', '-121.208313', '-121.1991763']}
# time: 4.97 ms (started: 2022-04-17 12:57:39 -05:00)

# %%
print(location.raw['address']['county'])
# Out:
# San Joaquin County
# time: 899 µs (started: 2022-04-17 12:57:39 -05:00)

# %% [markdown]
# ### Adding FIPS to weather_stations

# %%
#we had to edit the data in such a way to be able to access all locations within the reverse geocoder API limits
import pickle
# Out:
# time: 679 µs (started: 2022-04-17 12:57:39 -05:00)

# %%
with open('Desktop/550/geo_coordinates_to_area_info_dict_v2.pickle', 'rb') as f:
    d = pickle.load(f)
# Out:
# time: 10.4 ms (started: 2022-04-17 12:57:39 -05:00)

# %%
#view the resulting data structure
d
# Out:
# {'USC00412950': {'county': 'Zapata County',
#   'state': 'Texas',
#   'ISO3166-2-lvl4': 'US-TX',
#   'country': 'United States',
#   'country_code': 'us'},
#  'USW00003951': {'road': 'County Road 2127',
#   'hamlet': 'Stewart',
#   'state': 'Texas',
#   'ISO3166-2-lvl4': 'US-TX',
#   'country': 'United States',
#   'country_code': 'us'},
#  'USC00211174': {'road': 'County Road 103 Northwest',
#   'hamlet': 'Post Town',
#   'county': 'Olmsted County',
#   'state': 'Minnesota',
#   'country': 'United States',
#   'country_code': 'us'},
#  'USC00410779': {'house_number': '1066',
#   'road': 'North Texas Avenue',
#   'city': 'Big Lake',
#   'county': 'Reagan County',
#   'state': 'Texas',
#   'ISO3166-2-lvl4': 'US-TX',
#   'postcode': '76932',
#   'country': 'United States',
#   'country_code': 'us'},
#  'USC00411625': {'county': 'Erath County',
#   'state': 'Texas',
#   'ISO3166-2-lvl4': 'US-TX',
#   'country': 'United States',
#   'country_code': 'us'},
# ...

# %%
x = d.items()
type(x)
# Out:
# dict_items
# time: 985 µs (started: 2022-04-17 12:57:39 -05:00)

# %%
l= list(x)
l
h= l[0][0] #station name key for first list item
e=l[0][1] #dictionary of values
k= list(e.keys()) #list of keys in the dictionary
v=list(e.values()) #list of values in the dictionar
ind = k.index('county') #get the index of county
v[ind]
# Out:
# 'Zapata County'
# time: 2.39 ms (started: 2022-04-17 12:57:39 -05:00)

# %%
h= l[2][0]
h
# Out:
# 'USC00211174'
# time: 1.16 ms (started: 2022-04-17 12:57:39 -05:00)

# %%
l
# Out:
# [('USC00412950',
#   {'county': 'Zapata County',
#    'state': 'Texas',
#    'ISO3166-2-lvl4': 'US-TX',
#    'country': 'United States',
#    'country_code': 'us'}),
#  ('USW00003951',
#   {'road': 'County Road 2127',
#    'hamlet': 'Stewart',
#    'state': 'Texas',
#    'ISO3166-2-lvl4': 'US-TX',
#    'country': 'United States',
#    'country_code': 'us'}),
#  ('USC00211174',
#   {'road': 'County Road 103 Northwest',
#    'hamlet': 'Post Town',
#    'county': 'Olmsted County',
#    'state': 'Minnesota',
#    'country': 'United States',
#    'country_code': 'us'}),
#  ('USC00410779',
#   {'house_number': '1066',
#    'road': 'North Texas Avenue',
#    'city': 'Big Lake',
#    'county': 'Reagan County',
#    'state': 'Texas',
#    'ISO3166-2-lvl4': 'US-TX',
#    'postcode': '76932',
#    'country': 'United States',
#    'country_code': 'us'}),
#  ('USC00411625',
#   {'county': 'Erath County',
#    'state': 'Texas',
#    'ISO3166-2-lvl4': 'US-TX',
#    'country': 'United States',
# ...

# %%
weather_stations= climates
weather_stations.head(5)
# Out:
#     station_id  latitude            NAME  longitude  month temp_avg temp_min  \
# 0  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      1     56.5     45.4
# 1  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      2     60.3     48.4
# 2  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      3     68.1     56.4
# 3  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      4     74.6     63.1
# 4  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      5     80.5     69.8
#
#   temp_max rain_days snow_days
# 0     67.5      1.09
# 1     72.2      1.23
# 2     79.7       0.9
# 3     86.0      1.29
# 4     91.2      2.19
# time: 9.05 ms (started: 2022-04-17 12:57:40 -05:00)

# %%
#we're trying to get a list of county names 
#which will then be used to create a list of fips codes which we will then append to weather_stations
# Out:
# time: 214 µs (started: 2022-04-17 12:57:40 -05:00)

# %%
#list of station_ids from climates
# station_ids= climates['station_id'].unique()
station_ids= list(weather_stations['station_id'])
station_ids
# Out:
# ['USC00412950',
#  'USC00412950',
#  'USC00412950',
#  'USC00412950',
#  'USC00412950',
#  'USC00412950',
#  'USC00412950',
#  'USC00412950',
#  'USC00412950',
#  'USC00412950',
#  'USC00412950',
#  'USC00412950',
#  'USW00003951',
#  'USW00003951',
#  'USW00003951',
#  'USW00003951',
#  'USW00003951',
#  'USW00003951',
#  'USW00003951',
#  'USW00003951',
#  'USW00003951',
#  'USW00003951',
#  'USW00003951',
#  'USW00003951',
#  'USC00211174',
#  'USC00211174',
#  'USC00211174',
#  'USC00211174',
#  'USC00211174',
#  'USC00211174',
#  'USC00211174',
#  'USC00211174',
#  'USC00211174',
#  'USC00211174',
#  'USC00211174',
#  'USC00211174',
#  'USC00410779',
#  'USC00410779',
#  'USC00410779',
#  'USC00410779',
#  'USC00410779',
#  'USC00410779',
#  'USC00410779',
#  'USC00410779',
#  'USC00410779',
#  'USC00410779',
#  'USC00410779',
#  'USC00410779',
#  'USC00411625',
#  'USC00411625',
#  'USC00411625',
#  'USC00411625',
#  'USC00411625',
#  'USC00411625',
#  'USC00411625',
# ...

# %%
'USC00045032'in station_ids
# Out:
# True
# time: 1.86 ms (started: 2022-04-17 12:57:40 -05:00)

# %%
weather_stations = climates.filter(['station_id','NAME','latitude', 'longitude'], axis=1)

weather_stations.head(5)
# Out:
#     station_id            NAME  latitude  longitude
# 0  USC00412950  ESCOBAS, TX US  27.02667  -98.98083
# 1  USC00412950  ESCOBAS, TX US  27.02667  -98.98083
# 2  USC00412950  ESCOBAS, TX US  27.02667  -98.98083
# 3  USC00412950  ESCOBAS, TX US  27.02667  -98.98083
# 4  USC00412950  ESCOBAS, TX US  27.02667  -98.98083
# time: 4.84 ms (started: 2022-04-17 12:57:40 -05:00)

# %%
weather_stations.rename(columns={'station_id': 'id', 'NAME': 'name'}, inplace=True)
weather_stations.head(5)
# Out:
#             id            name  latitude  longitude
# 0  USC00412950  ESCOBAS, TX US  27.02667  -98.98083
# 1  USC00412950  ESCOBAS, TX US  27.02667  -98.98083
# 2  USC00412950  ESCOBAS, TX US  27.02667  -98.98083
# 3  USC00412950  ESCOBAS, TX US  27.02667  -98.98083
# 4  USC00412950  ESCOBAS, TX US  27.02667  -98.98083
# time: 5.1 ms (started: 2022-04-17 12:57:40 -05:00)

# %%
weather_stations = weather_stations.drop_duplicates()
# Out:
# time: 9.82 ms (started: 2022-04-17 12:57:40 -05:00)

# %%
len(weather_stations.id)
# Out:
# 2969
# time: 2.3 ms (started: 2022-04-17 12:57:40 -05:00)

# %%
l= list(x)
l
h= l[0][0] #station name key for first list item
e=l[0][1] #dictionary of values
k= list(e.keys()) #list of keys in the dictionary
v=list(e.values()) #list of values in the dictionar
ind = k.index('county') #get the index of county
v[ind]
# Out:
# 'Zapata County'
# time: 2.72 ms (started: 2022-04-17 12:57:40 -05:00)

# %%
v=l[2][1]
v
# Out:
# {'road': 'County Road 103 Northwest',
#  'hamlet': 'Post Town',
#  'county': 'Olmsted County',
#  'state': 'Minnesota',
#  'country': 'United States',
#  'country_code': 'us'}
# time: 2.31 ms (started: 2022-04-17 12:57:40 -05:00)

# %%
#sanity check to see of function makes sense
'hamlet' in v
# Out:
# True
# time: 2.13 ms (started: 2022-04-17 12:57:40 -05:00)

# %%
l
# Out:
# [('USC00412950',
#   {'county': 'Zapata County',
#    'state': 'Texas',
#    'ISO3166-2-lvl4': 'US-TX',
#    'country': 'United States',
#    'country_code': 'us'}),
#  ('USW00003951',
#   {'road': 'County Road 2127',
#    'hamlet': 'Stewart',
#    'state': 'Texas',
#    'ISO3166-2-lvl4': 'US-TX',
#    'country': 'United States',
#    'country_code': 'us'}),
#  ('USC00211174',
#   {'road': 'County Road 103 Northwest',
#    'hamlet': 'Post Town',
#    'county': 'Olmsted County',
#    'state': 'Minnesota',
#    'country': 'United States',
#    'country_code': 'us'}),
#  ('USC00410779',
#   {'house_number': '1066',
#    'road': 'North Texas Avenue',
#    'city': 'Big Lake',
#    'county': 'Reagan County',
#    'state': 'Texas',
#    'ISO3166-2-lvl4': 'US-TX',
#    'postcode': '76932',
#    'country': 'United States',
#    'country_code': 'us'}),
#  ('USC00411625',
#   {'county': 'Erath County',
#    'state': 'Texas',
#    'ISO3166-2-lvl4': 'US-TX',
#    'country': 'United States',
# ...

# %%
#create a county_name column and initially set to null
weather_stations['county_name']= np.nan
# Out:
# time: 1.27 ms (started: 2022-04-17 12:57:40 -05:00)

# %%
county_names=[]
for i in range(len(l)):
    st_name = l[i][0]
    if st_name in station_ids:
        #add county name to the list
        d = l[i][1]
        k = list(d.keys()) #list of keys in the dictionary
        v = list(d.values()) #list of values in the dictionary
        if 'county'in k:
            ind = k.index('county') #get the index of county
            c = v[ind]      
            weather_stations.loc[weather_stations["id"] == st_name, "county_name"] = c
        elif 'hamlet' in k:  
            ind = k.index('hamlet') #get the index of county
            c = v[ind]
            county_names.append(c)
            weather_stations.loc[weather_stations["id"] == st_name, "county_name"] = c
# Out:
# time: 1.9 s (started: 2022-04-17 12:58:33 -05:00)

# %%
#now that we have the county names in, we can now get the fips code
# Out:
# time: 435 µs (started: 2022-04-17 12:58:37 -05:00)

# %%
# climates['county_id'] = np.nan
# Out:
# time: 715 µs (started: 2022-04-17 12:58:38 -05:00)

# %%
fips = counties[counties['name'] == 'San Mateo'].fips_code
fips.iloc[0]
# Out:
# '06081'
# time: 28.8 ms (started: 2022-04-17 12:58:38 -05:00)

# %%
climates.head(5)
# Out:
#     station_id  latitude            NAME  longitude  month temp_avg temp_min  \
# 0  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      1     56.5     45.4
# 1  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      2     60.3     48.4
# 2  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      3     68.1     56.4
# 3  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      4     74.6     63.1
# 4  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      5     80.5     69.8
#
#   temp_max rain_days snow_days
# 0     67.5      1.09
# 1     72.2      1.23
# 2     79.7       0.9
# 3     86.0      1.29
# 4     91.2      2.19
# time: 26.7 ms (started: 2022-04-17 12:58:40 -05:00)

# %%
weather_list = list(weather_stations['county_name'])
# Out:
# time: 7.25 ms (started: 2022-04-17 12:58:45 -05:00)

# %%
len(weather_list)
# Out:
# 2969
# time: 7.04 ms (started: 2022-04-17 12:58:50 -05:00)

# %%
'Zapata' in list(counties['name'])
# Out:
# True
# time: 13.5 ms (started: 2022-04-17 12:58:52 -05:00)

# %%
#remove county in climate_list
# Out:
# time: 756 µs (started: 2022-04-17 12:58:55 -05:00)

# %%
county_name = []
# s = (list(zips['county_name']))
xword = "County" #word we want to remove since it is not used in zip file    

for i in range(len(weather_list)):
    county = weather_list [i]

    if not isinstance(county, float): #to account for data type
#remove the word county from the result
        words = county.split()
        for word in words:
            if word.lower() == xword.lower():
                words.remove(word)
                status = True

                if status:
                    county = ' '.join(words)
         
        county_name.append(county)
    else:
        county_name.append(county)
# Out:
# time: 9.01 ms (started: 2022-04-17 12:59:05 -05:00)

# %%
county_name
# Out:
# ['Zapata',
#  'Stewart',
#  'Olmsted',
#  'Reagan',
#  'Erath',
#  'Eastland',
#  'Jefferson',
#  'Freeborn',
#  'Nueces',
#  'Casey',
#  'Cameron',
#  'Itasca',
#  'Fillmore',
#  'Grant',
#  'Clay',
#  'Scott',
#  'Terrell',
#  'Wabasha',
#  'Howard',
#  'Coleman',
#  'Cook',
#  'Aransas',
#  'Fayette',
#  'Victoria',
#  'Faribault',
#  'Calhoun',
#  'Willacy',
#  'Grayson',
#  'Meeker',
#  'Calhoun',
#  'Goliad',
#  'Fannin',
#  'Victoria',
#  'Warren',
#  'Ellis',
#  'Dallas',
#  'Warren',
#  'Winona',
#  'Redwood',
#  'Aitkin',
#  'Oldham',
#  'Erath',
#  'Cass',
#  'Erath',
#  'Washington',
#  'Itasca',
#  'Clay',
#  'Presidio',
#  'Pecos',
#  'Cochran',
#  'Wilbarger',
#  'Hidalgo',
#  'Olmsted',
#  'Hennepin',
#  'Tyler',
#  'Trempealeau',
#  'Todd',
#  'Burnet',
#  'Le Sueur',
#  'Hennepin',
#  'Denton',
#  'Burnet',
#  'Lee',
#  'Denton',
#  'Montgomery',
#  'Sherburne',
#  'Beltrami',
#  'Bandera',
#  'Stearns',
#  'Carter',
#  'Pulaski',
#  'Liberty',
#  'King',
# ...

# %%
weather_stations['county_name']=county_name
# Out:
# time: 13 ms (started: 2022-04-17 12:59:13 -05:00)

# %%
weather_stations.head(10)
# Out:
#               id                     name  latitude  longitude county_name
# 0    USC00412950           ESCOBAS, TX US  27.02667  -98.98083      Zapata
# 12   USW00003951    LONGVIEW 11 SE, TX US  32.34660  -94.65330     Stewart
# 24   USC00211174             BYRON, MN US  44.09090  -92.64000     Olmsted
# 36   USC00410779        BIG LAKE 2, TX US  31.20010 -101.46260      Reagan
# 48   USC00411625    CHALK MOUNTAIN, TX US  32.15610  -97.93690       Erath
# 60   USC00412715          EASTLAND, TX US  32.39889  -98.81750    Eastland
# 72   USC00417172  PORT ARTHUR CITY, TX US  29.90440  -93.97080   Jefferson
# 84   USC00210075   ALBERT LEA 3 SE, MN US  43.60640  -93.30190    Freeborn
# 96   USC00417170      PORT ARANSAS, TX US  27.83810  -97.05930      Nueces
# 108  USC00156224              PHIL, KY US  37.16861  -84.93917       Casey
# time: 21.3 ms (started: 2022-04-17 12:59:22 -05:00)

# %%
#list of all the county names
s = list(counties['name'])
# Out:
# time: 8.26 ms (started: 2022-04-17 12:59:30 -05:00)

# %%
fips = counties.loc[counties['name']== 'Zapata', 'fips_code']
fips = fips.iloc[0]
# Out:
# time: 13.7 ms (started: 2022-04-17 12:59:33 -05:00)

# %%
weather_stations.loc[weather_stations["county_name"] == 'Zapata', "county_id"] = fips
weather_stations.head(5)
# Out:
#              id                   name  latitude  longitude county_name  \
# 0   USC00412950         ESCOBAS, TX US  27.02667  -98.98083      Zapata
# 12  USW00003951  LONGVIEW 11 SE, TX US  32.34660  -94.65330     Stewart
# 24  USC00211174           BYRON, MN US  44.09090  -92.64000     Olmsted
# 36  USC00410779      BIG LAKE 2, TX US  31.20010 -101.46260      Reagan
# 48  USC00411625  CHALK MOUNTAIN, TX US  32.15610  -97.93690       Erath
#
#    county_id
# 0      48505
# 12       NaN
# 24       NaN
# 36       NaN
# 48       NaN
# time: 22.7 ms (started: 2022-04-17 12:59:34 -05:00)

# %%
weather_stations.head(1)
# Out:
#             id            name  latitude  longitude county_name county_id
# 0  USC00412950  ESCOBAS, TX US  27.02667  -98.98083      Zapata     48505
# time: 17.5 ms (started: 2022-04-17 12:59:47 -05:00)

# %%
with open('Desktop/550/station_to_fips.pickle', 'rb') as f1:
    d1 = pickle.load(f1)
# Out:
# time: 8.95 ms (started: 2022-04-17 12:59:48 -05:00)

# %%
len(d1)
# Out:
# 2897
# time: 7.58 ms (started: 2022-04-17 12:59:49 -05:00)

# %%
#a list of the keys and a list of the values from above pickle file
k1 = list(d1.keys())
v1= list(d1.values())
# Out:
# time: 826 µs (started: 2022-04-17 12:59:52 -05:00)

# %%
station1 = weather_stations.iloc[0]['id']
station1
# Out:
# 'USC00412950'
# time: 9.64 ms (started: 2022-04-17 12:59:59 -05:00)

# %%
station1 in k1
# Out:
# True
# time: 55.4 ms (started: 2022-04-17 13:00:02 -05:00)

# %%
k1[1988]
# Out:
# 'USC00412950'
# time: 3.59 ms (started: 2022-04-17 13:00:03 -05:00)

# %%
# s2 = list(climates['station_id'])
vals3=[]
# for i, r in weather_stations.iterrows(): 
for i in range (len(weather_stations.id)):   
    station = weather_stations.iloc[i]['id']
    if station in k1:
        ind2 = k1.index(station)
#         print(ind2)
        fips = v1[ind2]
#         print(fips)
#         climates.loc[climates["station_id"] == station, "county_id"] = fips
        vals3.append(fips)
    else:
#         climates.loc[climates["station_id"] == station, "county_id"] = 0
        vals3.append(0)
# Out:
# time: 314 ms (started: 2022-04-17 13:01:22 -05:00)

# %%
weather_stations['county_id']=vals3
# Out:
# time: 54.4 ms (started: 2022-04-17 13:01:25 -05:00)

# %%
weather_stations.head(5)
# Out:
#              id                   name  latitude  longitude county_name  \
# 0   USC00412950         ESCOBAS, TX US  27.02667  -98.98083      Zapata
# 12  USW00003951  LONGVIEW 11 SE, TX US  32.34660  -94.65330     Stewart
# 24  USC00211174           BYRON, MN US  44.09090  -92.64000     Olmsted
# 36  USC00410779      BIG LAKE 2, TX US  31.20010 -101.46260      Reagan
# 48  USC00411625  CHALK MOUNTAIN, TX US  32.15610  -97.93690       Erath
#
#     county_id
# 0       48505
# 12          0
# 24      27109
# 36      48383
# 48      48143
# time: 24.3 ms (started: 2022-04-17 13:01:40 -05:00)

# %%
#drop county_ids with 0

weather_stations = weather_stations[weather_stations.county_id != 0]
# Out:
# time: 20.7 ms (started: 2022-04-17 13:02:14 -05:00)

# %%
#check length again
len(weather_stations['id'].unique())
# Out:
# 2897
# time: 13 ms (started: 2022-04-17 13:02:22 -05:00)

# %%
weather_stations.tail(5)
# Out:
#                id                                         name  latitude  \
# 5028  USC00041916                    COLGATE POWERHOUSE, CA US   39.3308
# 5040  USC00047339                          REDWOOD CITY, CA US   37.4767
# 5052  USC00040943  BODIE CALIFORNIA STATE HISTORIC PARK, CA US   38.2119
# 5064  USC00045032                                  LODI, CA US   38.1061
# 5076  USC00046006                      MOUNT WILSON CBS, CA US   34.2308
#
#       longitude  county_name  county_id
# 5028  -121.1922         Yuba       6115
# 5040  -122.2386    San Mateo       6081
# 5052  -119.0142         Mono       6051
# 5064  -121.2877  San Joaquin       6077
# 5076  -118.0711  Los Angeles       6037
# time: 29 ms (started: 2022-04-17 13:03:27 -05:00)

# %%
weather_stations.loc[weather_stations.county_id=='48505']
# Out:
# Empty DataFrame
# Columns: [id, name, latitude, longitude, county_name, county_id]
# Index: []
# time: 18.2 ms (started: 2022-04-17 13:03:29 -05:00)

# %%
counties.loc[counties.fips_code == '48141']
# Out:
#       fips_code     name state_id
# 27741     48141  El Paso       TX
# 27745     48141  El Paso       TX
# 27746     48141  El Paso       TX
# 27748     48141  El Paso       TX
# 27756     48141  El Paso       TX
# 27759     48141  El Paso       TX
# 27762     48141  El Paso       TX
# 27763     48141  El Paso       TX
# 27764     48141  El Paso       TX
# 27765     48141  El Paso       TX
# 27766     48141  El Paso       TX
# 27767     48141  El Paso       TX
# 27768     48141  El Paso       TX
# 27769     48141  El Paso       TX
# 27770     48141  El Paso       TX
# 27771     48141  El Paso       TX
# 27772     48141  El Paso       TX
# 27773     48141  El Paso       TX
# 27774     48141  El Paso       TX
# 27775     48141  El Paso       TX
# 27776     48141  El Paso       TX
# 27777     48141  El Paso       TX
# 27778     48141  El Paso       TX
# 27779     48141  El Paso       TX
# 27780     48141  El Paso       TX
# 27781     48141  El Paso       TX
# ...

# %%
weather_stations.info
# Out:
# <bound method DataFrame.info of                id                                         name  latitude  \
# 0     USC00412950                               ESCOBAS, TX US  27.02667
# 24    USC00211174                                 BYRON, MN US  44.09090
# 36    USC00410779                            BIG LAKE 2, TX US  31.20010
# 48    USC00411625                        CHALK MOUNTAIN, TX US  32.15610
# 60    USC00412715                              EASTLAND, TX US  32.39889
# ...           ...                                          ...       ...
# 5028  USC00041916                    COLGATE POWERHOUSE, CA US  39.33080
# 5040  USC00047339                          REDWOOD CITY, CA US  37.47670
# 5052  USC00040943  BODIE CALIFORNIA STATE HISTORIC PARK, CA US  38.21190
# 5064  USC00045032                                  LODI, CA US  38.10610
# 5076  USC00046006                      MOUNT WILSON CBS, CA US  34.23080
#
#       longitude  county_name  county_id
# ...

# %%
weather_stations.to_csv('Desktop/550/Weather_stations.csv')
# Out:
# time: 102 ms (started: 2022-04-17 13:03:45 -05:00)

# %% [markdown]
# #### Now filter out climate data

# %%
climates.head(2)
# Out:
#     station_id  latitude            NAME  longitude  month temp_avg temp_min  \
# 0  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      1     56.5     45.4
# 1  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      2     60.3     48.4
#
#   temp_max rain_days snow_days
# 0     67.5      1.09
# 1     72.2      1.23
# time: 26.2 ms (started: 2022-04-17 13:04:49 -05:00)

# %%
climates.loc[climates.station_id=='USC00040010']
# Out:
#        station_id  latitude                NAME  longitude  month temp_avg  \
# 2460  USC00040010   38.2177  ACAMPO 5 NE, CA US  -121.2013      1
# 2461  USC00040010   38.2177  ACAMPO 5 NE, CA US  -121.2013      2
# 2462  USC00040010   38.2177  ACAMPO 5 NE, CA US  -121.2013      3
# 2463  USC00040010   38.2177  ACAMPO 5 NE, CA US  -121.2013      4
# 2464  USC00040010   38.2177  ACAMPO 5 NE, CA US  -121.2013      5
# 2465  USC00040010   38.2177  ACAMPO 5 NE, CA US  -121.2013      6
# 2466  USC00040010   38.2177  ACAMPO 5 NE, CA US  -121.2013      7
# 2467  USC00040010   38.2177  ACAMPO 5 NE, CA US  -121.2013      8
# 2468  USC00040010   38.2177  ACAMPO 5 NE, CA US  -121.2013      9
# 2469  USC00040010   38.2177  ACAMPO 5 NE, CA US  -121.2013     10
# 2470  USC00040010   38.2177  ACAMPO 5 NE, CA US  -121.2013     11
# 2471  USC00040010   38.2177  ACAMPO 5 NE, CA US  -121.2013     12
#
#      temp_min temp_max rain_days snow_days
# 2460                        3.45       0.0
# ...

# %%
climates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35628 entries, 0 to 5087
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   station_id  35628 non-null  object
#  1   latitude    35628 non-null  float64
#  2   NAME        35628 non-null  object
#  3   longitude   35628 non-null  float64
#  4   month       35628 non-null  int64
#  5   temp_avg    35628 non-null  object
#  6   temp_min    35628 non-null  object
#  7   temp_max    35628 non-null  object
#  8   rain_days   35628 non-null  object
#  9   snow_days   35628 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 3.0+ MB
# time: 104 ms (started: 2022-04-17 13:05:09 -05:00)

# %%
climates.rename(columns={'NAME': 'name'}, inplace=True)
# Out:
# time: 2.64 ms (started: 2022-04-17 13:05:13 -05:00)

# %%
climates.head(5)
# Out:
#     station_id  latitude            name  longitude  month temp_avg temp_min  \
# 0  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      1     56.5     45.4
# 1  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      2     60.3     48.4
# 2  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      3     68.1     56.4
# 3  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      4     74.6     63.1
# 4  USC00412950  27.02667  ESCOBAS, TX US  -98.98083      5     80.5     69.8
#
#   temp_max rain_days snow_days
# 0     67.5      1.09
# 1     72.2      1.23
# 2     79.7       0.9
# 3     86.0      1.29
# 4     91.2      2.19
# time: 21.2 ms (started: 2022-04-17 13:05:14 -05:00)

# %%
climates.to_csv('Desktop/550/ClimatesF.csv')
# Out:
# time: 211 ms (started: 2022-04-17 13:05:14 -05:00)

# %% [markdown]
# # Jobs Data

# %%
#getting the list of sheet names in the excel file
x2 = pd.ExcelFile('/content/gdrive/My Drive/550/DataSets/Wage and Job Numbers/MSA_M2020_dl.xlsx')
sn1 = x2.sheet_names
sn1

# %%
jobs1 = pd.read_excel('/content/gdrive/My Drive/550/DataSets/Wage and Job Numbers/MSA_M2020_dl.xlsx')
jobs1.head (5)

# %%
#getting the list of sheet names in the excel file
x3 = pd.ExcelFile('/content/gdrive/My Drive/550/DataSets/Wage and Job Numbers/BOS_M2020_dl.xlsx')
sn2 = x3.sheet_names
sn2

# %%
jobs2 = pd.read_excel('/content/gdrive/My Drive/550/DataSets/Wage and Job Numbers/BOS_M2020_dl.xlsx')
jobs2.head (5)

# %%
area = pd.read_csv('/content/gdrive/My Drive/550/DataSets/area_definitions_m2020.csv')

# %%
area.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4937 entries, 0 to 4936
# Data columns (total 9 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   FIPS code                                                  4937 non-null   int64
#  1   State                                                      4937 non-null   object
#  2   State abbreviation                                         4937 non-null   object
#  3   May 2020 MSA code                                          4937 non-null   int64
#  4   May 2020 MSA name                                          4937 non-null   object
#  5   County code                                                4937 non-null   int64
#  6   Area Code                                                  4937 non-null   int64
#  7   Township code                                              4937 non-null   int64
# ...

# %%
area1 = area.drop( area[ area['State abbreviation'] == 'PR' ].index , inplace=True)

# %%
indexNames = area[ (area['State abbreviation'] == 'PR')].index

# %%
area.drop(indexNames, inplace = True)

# %%
area.info()
area.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4856 entries, 0 to 4855
# Data columns (total 9 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   FIPS code                                                  4856 non-null   int64
#  1   State                                                      4856 non-null   object
#  2   State abbreviation                                         4856 non-null   object
#  3   May 2020 MSA code                                          4856 non-null   int64
#  4   May 2020 MSA name                                          4856 non-null   object
#  5   County code                                                4856 non-null   int64
#  6   Area Code                                                  4856 non-null   int64
#  7   Township code                                              4856 non-null   int64
# ...

# %%
area_update = area.filter(['May 2020 MSA code', 'Area Code'], axis=1)
area_update.head(5)
# Out:
#    Area Code
# 0       1001
# 1       1003
# 2       1005
# 3       1007
# 4       1009

# %%
jobs1_t = jobs1.filter(['OCC_CODE', 'OCC_TITLE'], axis=1)
jobs1_t.head(5)

# %%
jobs1_t.rename(columns={'OCC_CODE': 'code', 'OCC_TITLE':'title'}, inplace=True)
jobs1_t.head(5)

# %%
jobs2_t = jobs2.filter(['OCC_CODE', 'OCC_TITLE'], axis=1)
jobs2_t.head(5)

# %%
jobs1_t.to_csv('/content/gdrive/My Drive/550/DataSets/Jobs1.csv')

# %%
jobs2_t.rename(columns={'OCC_CODE': 'code', 'OCC_TITLE':'title'}, inplace=True)
jobs2_t.head(5)

# %%
#concatenate all for dataframes
jobs = pd.concat([jobs1_t, jobs2_t])
jobs.head(5)

# %%
jobs.info()

# %%
jobs.describe()

# %%
list(jobs.columns)

# %%
jobsupdated = jobs.drop_duplicates(subset=['title'])

# %%
jobsupdated['code'] = jobsupdated['code'].str.lstrip()
print (jobsupdated)

# %%
jobsupdated['title'] = jobsupdated['title'].str.lstrip()
print (jobs)

# %% [markdown]
# ##Jobs

# %%
jobsupdated.to_csv('/content/gdrive/My Drive/550/DataSets/Jobsupdated.csv')

# %% [markdown]
# ##Employment

# %%
employment1 = pd.concat([jobs1, jobs2])
employment1.head(5)

# %%
employment = employment1.filter(['AREA', 'OCC_CODE','TOT_EMP','A_MEAN','LOC_QUOTIENT'], axis=1)
employment.head(5)

# %%
employment.drop( employment[ employment['PRIM_STATE'] == 'PR' ].index , inplace=True)

# %%
employment.rename(columns={'AREA': 'occ-zone', 'OCC_CODE':'job_code', 'TOT_EMP':'total_jobs', 'A_MEAN': 'mean_salary','LOC_QUOTIENT': 'location_quotient' }, inplace=True)
employment.head(5)

# %%
employment['job_code'] = employment['job_code'].str.lstrip()
print (employment)

# %%
employment.info()

# %%
employment.to_csv('/content/gdrive/My Drive/550/DataSets/Employment.csv', index = False)

# %%
missing_value = ["*", "**", "#"]
employment2 = pd.read_csv('/content/gdrive/My Drive/550/DataSets/Employment.csv', na_values=missing_value)

# %%
#Removing the * or ** values
employment2.isnull().sum()

# %%
em = employment2.dropna()
em.isnull().sum()
em.info()

# %%
newdf = em.drop_duplicates(
  subset = ['occ-zone', 'job_code'],
  keep = 'last').reset_index(drop = True)

# %%
em.to_csv('/content/gdrive/My Drive/550/DataSets/Employment.csv')

# %%
import numpy as np
no_of_rows = 20000
for k,g in em.groupby(np.arange(len(em))//no_of_rows):
    g.to_csv('/content/gdrive/My Drive/550/DataSets/Employment{}.csv'.format(k+1), index=False)

# %% [markdown]
# #Regions

# %%
lst = ['West', 'Midwest', 'Northeast', 'South', 'Territory']
regions = pd.DataFrame(lst, columns =['name'])
regions

# %%
regions.to_csv('/content/gdrive/My Drive/550/DataSets/Regions.csv')

# %% [markdown]
# ##States

# %%
lst = ['Alabama','Alaska', 'Arizona','Arkansas','California', 'Colorado','Connecticut','Delaware',
       'Florida','Georgia','Hawaii','Idaho','Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana',
       'Maine','Maryland','Massachusetts','Michigan','Minnesota','Mississippi','Missouri','Montana',
       'Nebraska','Nevada','New Hampshire','New Jersey','New Mexico','New York','North Carolina',
       'North Dakota','Ohio','Oklahoma','Oregon','Pennsylvania','Rhode Island','South Carolina',
       'South Dakota','Tennessee','Texas','Utah','Vermont','Virginia','Washington','West Virginia',
       'Wisconsin','Wyoming']

lst2= ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA', 'HI', 'ID','IL','IN','IA','KS','KY','LA','ME',
       'MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA', 'RI',
       'SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY', 'PR']
  
lst3= [3, 0, 0,3,0,0,2,3,3,3,0,0,1,1,1,1,3,3,2,
       3,2,1,1,3,1,0,1,0,2,2,0,2,3,1,1,3,0,2,2,
       3,1,3,3,0,2,3,0,3,1,0,4]

# %%
states = pd.DataFrame(list(zip(lst, lst2, lst3)),
               columns =['id', 'name', 'region_id'])
states.head(10)

# %%
states.to_csv('/content/gdrive/My Drive/550/DataSets/States.csv')
